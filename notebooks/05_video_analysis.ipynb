# %%
# From https://www.youtube.com/playlist?list=PLhSo4yNIY29N8QmHaC5HtASTikJpE91Hb
video_details = {
    'CUP21-00015': {
        'link': 'https://www.youtube.com/watch?v=zDnYBM_wldM',
        'start': 3664,
        'deliberation': 5385,
        'end': 5622,
        'notable_times': {
            4351: 'Legal standard for City Council\'s Review (presumptively valid)',
            5405: 'Clegg: "As I listened to the testimony I did not hear anyone suggest that there was an error in that decision, nor could I find one. And with that, I would move to deny the appeal and uphold the decision of the planning and zoning commission..."',
            5590: 'Bageant: "When I look at our standard of review for commission decisions...   I don\'t see anything that rises to the level of "error", so I\'ll be supporting the motion."',
        }
    },
    'CUP22-00007': {
        'link': 'https://www.youtube.com/watch?v=iJ__Zx54ey0',
        'start': 2611,
        'deliberation': 5034,
        'end': 5402,
        'notable_times': {
            5095: 'Bageant: "The Planning and Zoning [Commission]\'s reasoning wasn\'t substantively wrong or in error"',
            5205: 'Hallyburton: "When we look at an appeal it\'s a pretty narrow scope of what we\'re able to do, based off of re-looking at the evidence"'
        }
    },
    'CUP22-00068': {
        'link': 'https://www.youtube.com/watch?v=zytsB3ZNUME',
        'start': 10850,
        'deliberation': 13114,
        'end': 13296,
        'notable_times': {
            13210: 'Bageant: "All we have to decide, and all we should decide, is whether the planning and zoning commission erred"'
        }
    },
    'CUP23-00047': {
        'link': 'https://www.youtube.com/watch?v=V65D3d8-1rA',
        'start': 3846,
        'deliberation': 5884,
        'end': 6081,
        'notable_times': {
            4046: 'Staff: "The cited ground does not constitute an error made by the Commission"',
            5929: 'Bageant: Explains the errors made by PZC'
        }
    },
    'CUP23-00057': {
        'link': 'https://www.youtube.com/watch?v=dww9c7jlURc',
        'start': 399,
        'deliberation': 7914,
        'end': 9452,
        'notable_times': {
            676: 'Staff: The grounds for the appeal specifically refer to the code\'s definition of "error" and the PZC\'s failure to apply the code correctly',
            8129: 'Nash: "I think the next two things that we\'re going to consider [(the CUP)], I think we have a lot less leeway in there..."'
        }
    },
    'CUP23-00079': {
        'link': 'https://www.youtube.com/watch?v=-XX6qMGeZec',
        'start': 4321,
        'deliberation': 6269,
        'end': 6620,
        'notable_times': {
            4593: 'Staff: No error demonstrated, slides showing standard for review',
            5777: 'Willits: "We [don\'t] rediscuss everything that Planning and Zoning did; we have to look at very specific things, so as part of the standards of review we have six things that we have to look at."',
            6271: 'Female Councilwoman: "I do not find that there was a demonstrated error in the decision of the Planning and Zoning Commission"',
            6287: 'Morales: "I do not see error in the findings from our Planning and Zoning in this one..."',
            6473: 'Hallyburton: "Our job here on an appeal is to really look at the standard of reviews for appeals... I don\'t see how we can overturn an appeal without an error that Planning and Zoning made in that meeting."'
        }
    },
    'CUP24-00011': {
        'link': 'https://www.youtube.com/watch?v=wFMORuaM4cg',
        'start': 2332,
        'deliberation': 5335,
        'end': 5890,
        'notable_times': {
            2748: 'Staff: "The grounds for where council can find error with the decision are on your screen"',
            5344: 'Stead: "There is no evidence that the commission erred in its decision..."',
            5380: 'Stead: "It is our discretion to make exceptions to things like height..."'
        }
    },
    'CUP24-00012': {
        'link': 'https://www.youtube.com/watch?v=ICB8_s8ZKb8',
        'start': 802,
        'deliberation': 10283,
        'end': 11640,
        'notable_times': {
            10624: 'Stead makes some claims of an arbitrary decision by PZC'
        }
    }
}

# %%
# Generate links for every notable time
for record_id, details in video_details.items():
    link = details['link']
    notable_times = details['notable_times']

    print(f'Record: {record_id}')
    # Generate links for notable times
    for time, description in notable_times.items():
        link_url = f"{link}&t={time}s"
        print(f"{description}    {link_url}")
        print()

    print()
    print()
# Out:
# Record: CUP21-00015
# Legal standard for City Council's Review (presumptively valid)    https://www.youtube.com/watch?v=zDnYBM_wldM&t=4351s
#
# Clegg: "As I listened to the testimony I did not hear anyone suggest that there was an error in that decision, nor could I find one. And with that, I would move to deny the appeal and uphold the decision of the planning and zoning commission..."    https://www.youtube.com/watch?v=zDnYBM_wldM&t=5405s
#
# Bageant: "When I look at our standard of review for commission decisions...   I don't see anything that rises to the level of "error", so I'll be supporting the motion."    https://www.youtube.com/watch?v=zDnYBM_wldM&t=5590s
#
#
#
# Record: CUP22-00007
# Bageant: "The Planning and Zoning [Commission]'s reasoning wasn't substantively wrong or in error"    https://www.youtube.com/watch?v=iJ__Zx54ey0&t=5095s
#
# ...
